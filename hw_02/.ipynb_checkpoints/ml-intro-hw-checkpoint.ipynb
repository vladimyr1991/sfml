# %% [markdown]
# # SkillFactory
# ## Введение в ML, введение в sklearn

# %% [markdown]
# В этом задании мы с вами рассмотрим данные с конкурса [Задача предсказания отклика клиентов ОТП Банка](http://www.machinelearning.ru/wiki/index.php?title=%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BF%D1%80%D0%B5%D0%B4%D1%81%D0%BA%D0%B0%D0%B7%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BE%D1%82%D0%BA%D0%BB%D0%B8%D0%BA%D0%B0_%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2_%D0%9E%D0%A2%D0%9F_%D0%91%D0%B0%D0%BD%D0%BA%D0%B0_%28%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%29)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,5)

# %% [markdown]
# ### Грузим данные

# %% [markdown]
# Считаем описание данных

# %%
df_descr = pd.read_csv('data/otp_description.csv', sep='\t', encoding='utf8')

# %%
df_descr
# Out:
#                           ПОЛЕ  \
# 0                 AGREEMENT_RK
# 1                          AGE
# 2            SOCSTATUS_WORK_FL
# 3            SOCSTATUS_PENS_FL
# 4                       GENDER
# 5                  CHILD_TOTAL
# 6                   DEPENDANTS
# 7                    EDUCATION
# 8               MARITAL_STATUS
# 9                 GEN_INDUSTRY
# 10                   GEN_TITLE
# 11                ORG_TP_STATE
# 12             ORG_TP_FCAPITAL
# 13                     JOB_DIR
# 14               FAMILY_INCOME
# 15             PERSONAL_INCOME
# 16        REG_ADDRESS_PROVINCE
# 17       FACT_ADDRESS_PROVINCE
# 18     POSTAL_ADDRESS_PROVINCE
# 19                 TP_PROVINCE
# 20                   REGION_NM
# 21                 REG_FACT_FL
# 22                FACT_POST_FL
# 23                 REG_POST_FL
# 24            REG_FACT_POST_FL
# 25         REG_FACT_POST_TP_FL
# 26              FL_PRESENCE_FL
# 27                    OWN_AUTO
# 28                 AUTO_RUS_FL
# 29              HS_PRESENCE_FL
# 30             COT_PRESENCE_FL
# 31             GAR_PRESENCE_FL
# 32            LAND_PRESENCE_FL
# 33                      CREDIT
# 34                        TERM
# 35                 FST_PAYMENT
# 36              DL_DOCUMENT_FL
# 37             GPF_DOCUMENT_FL
# 38            FACT_LIVING_TERM
# 39                   WORK_TIME
# 40               FACT_PHONE_FL
# 41                REG_PHONE_FL
# 42                GEN_PHONE_FL
# 43              LOAN_NUM_TOTAL
# 44             LOAN_NUM_CLOSED
# 45               LOAN_NUM_PAYM
# 46                LOAN_DLQ_NUM
# 47                LOAN_MAX_DLQ
# 48            LOAN_AVG_DLQ_AMT
# 49            LOAN_MAX_DLQ_AMT
# 50  PREVIOUS_CARD_NUM_UTILIZED
#
#                                              ОПИСАНИЕ
# 0          уникальный идентификатор объекта в выборке
# 1                                     возраст клиента
# 2   социальный статус клиента относительно работы ...
# 3   социальный статус клиента относительно пенсии ...
# 4                 пол клиента (1- женщины, 0-мужчины)
# 5                            количество детей клиента
# 6                       количество иждивенцев клиента
# 7                                         образование
# 8                                  семейное положение
# 9                              отрасль работы клиента
# 10                                          должность
# 11                       форма собственности компании
# 12                  отношение к иностранному капиталу
# 13          направление деятельности в нутри компании
# 14               семейный доход (несколько категорий)
# 15                    личный доход клиента (в рублях)
# 16                        область регистрации клиента
# 17            область фактического пребывания клиента
# 18                             почтовый адрес область
# 19  область торговой точки, где клиент брал послед...
# 20                                          регион РФ
# 21  адрес регистрации и адрес фактического пребыва...
# 22  адрес фактического пребывания клиента и его по...
# 23  адрес регистрации клиента и его почтовый адрес...
# 24  почтовый, фактический и адрес регистрации совп...
# 25  область регистрации, фактического пребывания, ...
# 26  наличие в собственности квартиры (1 - есть, 0 ...
# 27                кол-во автомобилей в собственности
# 28  наличие в собственности автомобиля российского...
# 29  наличие в собственности загородного дома (1 - ...
# 30  наличие в собственности котеджа (1 - есть, 0 -...
# 31  наличие в собственности гаража (1 - есть, 0 - ...
# 32  наличие в собственности земельного участка (1 ...
# 33        сумма последнего кредита клиента (в рублях)
# 34                                       срок кредита
# 35                    первоначальный взнос (в рублях)
# 36  в анкете клиент указал водительское удостовере...
# 37  в анкете клиен указал ГПФ (1 - указал, 0 - не ...
# 38  количество месяцев проживания по месту фактиче...
# 39          время работы на текущем месте (в месяцах)
# 40  наличие в заявке телефона по фактическому мест...
# 41     наличие в заявке телефона по месту регистрации
# 42                 наличие в заявке рабочего телефона
# 43                            количество ссуд клиента
# 44                 количество погашенных ссуд клиента
# 45         количество платежей, которые сделал клиент
# 46          количество просрочек, допущенных клиентом
# 47  номер максимальной просрочки, допущенной клиентом
# 48                 средняя сумма просрочки (в рублях)
# 49            максимальная сумма просрочки (в рублях)
# 50  количество уже утилизированных карт ( если пус...

# %% [markdown]
# Считаем обучающую выборки и тестовую (которую мы как бы не видим)

# %%
df_train = pd.read_csv('data/otp_train.csv', sep='\t', encoding='utf8')

# %%
df_train.shape
# Out:
# (15223, 52)

# %%
df_test = pd.read_csv('data/otp_test.csv', sep='\t', encoding='utf8')

# %%
df_test.shape
# Out:
# (14910, 52)

# %%
df_train.head()
# Out:
#    AGREEMENT_RK  TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0      59910150       0   49                  1                  0       1
# 1      59910230       0   32                  1                  0       1
# 2      59910525       0   52                  1                  0       1
# 3      59910803       0   39                  1                  0       1
# 4      59911781       0   30                  1                  0       0
#
#    CHILD_TOTAL  DEPENDANTS            EDUCATION  MARITAL_STATUS  \
# 0            2           1  Среднее специальное  Состою в браке
# 1            3           3              Среднее  Состою в браке
# 2            4           0     Неполное среднее  Состою в браке
# 3            1           1               Высшее  Состою в браке
# 4            0           0              Среднее  Состою в браке
#
#              ...             REG_PHONE_FL GEN_PHONE_FL LOAN_NUM_TOTAL  \
# 0            ...                        0            1              1
# 1            ...                        0            1              1
# 2            ...                        0            1              2
# 3            ...                        1            1              1
# 4            ...                        0            1              2
#
#   LOAN_NUM_CLOSED LOAN_NUM_PAYM LOAN_DLQ_NUM LOAN_MAX_DLQ  LOAN_AVG_DLQ_AMT  \
# 0               1             6            2            1              1580
# 1               1             6            1            1              4020
# 2               1            11            0            0                 0
# 3               1             6            3            1  1589,92333333333
# 4               1            16            2            1           1152,15
#
#   LOAN_MAX_DLQ_AMT PREVIOUS_CARD_NUM_UTILIZED
# 0             1580                        NaN
# 1             4020                        NaN
# 2                0                        NaN
# 3             1590                        NaN
# 4             2230                        NaN
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Объединим две выборки
#
# Так как пока мы пока не умеем работать sklearn  Pipeline, то для того, чтобы после предобработки столбцы в двух выборках находились на своих местах.
#
# Для того, чтобы в дальнейшем отделить их введем новый столбец "sample"

# %%
df_train.loc[:, 'sample'] = 'train'
df_test.loc[:, 'sample'] = 'test'

# %%
df = df_test.append(df_train).reset_index(drop=True)

# %%
df.shape
# Out:
# (30133, 53)

# %% [markdown]
# ### Чуть-чуть посмотрим на данные

# %% [markdown]
# Посмотрим типы данных и их заполняемость

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  30133 non-null int64
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null object
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null object
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null object
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null object
# LOAN_MAX_DLQ_AMT              30133 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# sample                        30133 non-null object
# dtypes: float64(2), int64(32), object(19)
# memory usage: 12.2+ MB

# %% [markdown]
# Видим, что часть данных - object, скорее всего стоки.
#
#
# Давайте выведем эти значения для каждого столбца

# %%
for i in df_train.columns: # перебираем все столбцы
    if str(df_train[i].dtype) == 'object': # если тип столбца - object
        print('='*10)
        print(i) # выводим название столбца
        print(set(df_train[i])) # выводим все его значения (но делаем set - чтоб значения не повторялись)
        print('\n') # выводим пустую строку
# Out:
# ==========
# EDUCATION
# {'Среднее', 'Высшее', 'Два и более высших образования', 'Ученая степень', 'Неоконченное высшее', 'Среднее специальное', 'Неполное среднее'}
#
#
# ==========
# MARITAL_STATUS
# {'Разведен(а)', 'Вдовец/Вдова', 'Не состоял в браке', 'Состою в браке', 'Гражданский брак'}
#
#
# ==========
# GEN_INDUSTRY
# {nan, 'Информационные услуги', 'Недвижимость', 'Строительство', 'Металлургия/Промышленность/Машиностроение', 'Сельское хозяйство', 'Банк/Финансы', 'Развлечения/Искусство', 'Логистика', 'ЧОП/Детективная д-ть', 'СМИ/Реклама/PR-агенства', 'Коммунальное хоз-во/Дорожные службы', 'Транспорт', 'Другие сферы', 'Маркетинг', 'Туризм', 'Нефтегазовая промышленность', 'Энергетика', 'Информационные технологии', 'Государственная служба', 'Юридические услуги/нотариальные услуги', 'Сборочные производства', 'Здравоохранение', 'Подбор персонала', 'Образование', 'Химия/Парфюмерия/Фармацевтика', 'Страхование', 'Наука', 'Торговля', 'Салоны красоты и здоровья', 'Управляющая компания', 'Ресторанный бизнес/Общественное питание'}
#
#
# ==========
# GEN_TITLE
# {nan, 'Индивидуальный предприниматель', 'Работник сферы услуг', 'Служащий', 'Военнослужащий по контракту', 'Руководитель высшего звена', 'Высококвалифиц. специалист', 'Руководитель низшего звена', 'Другое', 'Рабочий', 'Партнер', 'Специалист', 'Руководитель среднего звена'}
#
#
# ==========
# ORG_TP_STATE
# {nan, 'Индивидуальный предприниматель', 'Некоммерческая организация', 'Частная компания', 'Частная ком. с инос. капиталом', 'Государственная комп./учреж.'}
#
#
# ==========
# ORG_TP_FCAPITAL
# {nan, 'Без участия', 'С участием'}
#
#
# ==========
# JOB_DIR
# {'Служба безопасности', nan, 'Юридическая служба', 'Адм-хоз. и трансп. службы', 'Вспомогательный техперсонал', 'Бухгалтерия, финансы, планир.', 'Пр-техн. обесп. и телеком.', 'Реклама и маркетинг', 'Кадровая служба и секретариат', 'Участие в основ. деятельности', 'Снабжение и сбыт'}
#
#
# ==========
# FAMILY_INCOME
# {'от 10000 до 20000 руб.', 'до 5000 руб.', 'свыше 50000 руб.', 'от 20000 до 50000 руб.', 'от 5000 до 10000 руб.'}
#
#
# ==========
# PERSONAL_INCOME
# {
}
#
#
# ==========
# FACT_ADDRESS_PROVINCE
# {'Читинская область', 'Иркутская область', 'Свердловская область', 'Коми', 'Приморский край', 'Адыгея', 'Саратовская область', 'Орловская область', 'Кемеровская область', 'Оренбургская область', 'Хакасия', 'Тамбовская область', 'Горный Алтай', 'Тульская область', 'Ханты-Мансийский АО', 'Ульяновская область', 'Нижегородская область', 'Владимирская область', 'Вологодская область', 'Магаданская область', 'Ростовская область', 'Калужская область', 'Амурская область', 'Пензенская область', 'Тюменская область', 'Новгородская область', 'Бурятия', 'Курганская область', 'Калининградская область', 'Марийская республика', 'Чувашия', 'Москва', 'Костромская область', 'Еврейская АО', 'Якутия', 'Ямало-Ненецкий АО', 'Краснодарский край', 'Эвенкийский АО', 'Пермская область', 'Ставропольский край', 'Липецкая область', 'Кировская область', 'Дагестан', 'Рязанская область', 'Хабаровский край', 'Самарская область', 'Санкт-Петербург', 'Смоленская область', 'Астраханская область', 'Тверская область', 'Новосибирская область', 'Удмуртия', 'Мордовская республика', 'Московская область', 'Агинский Бурятский АО', 'Белгородская область', 'Волгоградская область', 'Карелия', 'Ярославская область', 'Мурманская область', 'Ивановская область', 'Ленинградская область', 'Карачаево-Черкесия', 'Северная Осетия', 'Усть-Ордынский Бурятский АО', 'Кабардино-Балкария', 'Башкирия', 'Псковская область', 'Красноярский край', 'Курская область', 'Архангельская область', 'Сахалинская область', 'Калмыкия', 'Брянская область', 'Омская область', 'Челябинская область', 'Томская область', 'Камчатская область', 'Воронежская область', 'Алтайский край', 'Татарстан'}
#
#
# ==========
# POSTAL_ADDRESS_PROVINCE
# {'Читинская область', 'Иркутская область', 'Свердловская область', 'Коми', 'Приморский край', 'Адыгея', 'Саратовская область', 'Орловская область', 'Кемеровская область', 'Оренбургская область', 'Хакасия', 'Тамбовская область', 'Горный Алтай', 'Тульская область', 'Ханты-Мансийский АО', 'Ульяновская область', 'Нижегородская область', 'Владимирская область', 'Вологодская область', 'Магаданская область', 'Ростовская область', 'Калужская область', 'Амурская область', 'Пензенская область', 'Тюменская область', 'Новгородская область', 'Бурятия', 'Курганская область', 'Калининградская область', 'Марийская республика', 'Чувашия', 'Москва', 'Костромская область', 'Еврейская АО', 'Якутия', 'Ямало-Ненецкий АО', 'Краснодарский край', 'Эвенкийский АО', 'Калмыкия', 'Пермская область', 'Ставропольский край', 'Липецкая область', 'Кировская область', 'Рязанская область', 'Хабаровский край', 'Самарская область', 'Санкт-Петербург', 'Смоленская область', 'Астраханская область', 'Тверская область', 'Новосибирская область', 'Удмуртия', 'Мордовская республика', 'Московская область', 'Агинский Бурятский АО', 'Белгородская область', 'Волгоградская область', 'Карелия', 'Ярославская область', 'Мурманская область', 'Ивановская область', 'Ленинградская область', 'Карачаево-Черкесия', 'Северная Осетия', 'Кабардино-Балкария', 'Башкирия', 'Псковская область', 'Красноярский край', 'Курская область', 'Архангельская область', 'Сахалинская область', 'Усть-Ордынский Бурятский АО', 'Брянская область', 'Омская область', 'Челябинская область', 'Томская область', 'Камчатская область', 'Воронежская область', 'Алтайский край', 'Татарстан'}
#
#
# ==========
# TP_PROVINCE
# {nan, 'Читинская область', 'Иркутская область', 'Свердловская область', 'Коми', 'Приморский край', 'Адыгея', 'Саратовская область', 'Орловская область', 'Кемеровская область', 'Оренбургская область', 'Тамбовская область', 'Горный Алтай', 'Тульская область', 'Ханты-Мансийский АО', 'Ульяновская область', 'Нижегородская область', 'Владимирская область', 'Вологодская область', 'Магаданская область', 'Ростовская область', 'Калужская область', 'Амурская область', 'Пензенская область', 'Тюменская область', 'Новгородская область', 'Бурятия', 'Курганская область', 'Калининградская область', 'Марийская республика', 'Чувашия', 'Москва', 'Костромская область', 'Еврейская АО', 'Якутия', 'Краснодарский край', 'Пермская область', 'Ставропольский край', 'Липецкая область', 'Кировская область', 'Рязанская область', 'Хабаровский край', 'Самарская область', 'Санкт-Петербург', 'Смоленская область', 'Астраханская область', 'Тверская область', 'Новосибирская область', 'Удмуртия', 'Мордовская республика', 'Белгородская область', 'Волгоградская область', 'Карелия', 'Ярославская область', 'Мурманская область', 'Ивановская область', 'Кабардино-Балкария', 'Башкирия', 'Псковская область', 'Красноярский край', 'Курская область', 'Архангельская область', 'Сахалинская область', 'Брянская область', 'Омская область', 'Челябинская область', 'Томская область', 'Камчатская область', 'Воронежская область', 'Алтайский край', 'Татарстан'}
#
#
# ==========
# REGION_NM
# {'ЮЖНЫЙ', nan, 'СЕВЕРО-ЗАПАДНЫЙ', 'ВОСТОЧНО-СИБИРСКИЙ', 'ПРИВОЛЖСКИЙ', 'ЗАПАДНО-СИБИРСКИЙ', 'УРАЛЬСКИЙ', 'ДАЛЬНЕВОСТОЧНЫЙ', 'ЦЕНТРАЛЬНЫЙ ОФИС', 'ПОВОЛЖСКИЙ', 'ЦЕНТРАЛЬНЫЙ 1', 'ЦЕНТРАЛЬНЫЙ 2'}
#
#
# ==========
# CREDIT
# {'11876', '16620', '16977', '19895', '14190', '34618', '8597', '23954', '41907', '38625', '5941', '7999', '25897,4', '22394', '8990,9', '22692', '9215', '12900', '10470', '11477', '21484', '9800', '11070', '8700', '5017,9', '15246', '14599', '16883', '19390', '17826', '4241', '7850', '17398,2', '22987', '3196', '24881', '19570', '21000', '14820', '11615,4', '11167', '10024', '63306', '6295', '7368', '13975', '12197', '18190', '5710', '28070', '12198', '8532', '12249', '19772', '14098,1', '27149', '17298', '20601', '18749', '10837', '20397', '20999', '34154', '21440', '10339', '29285', '18001,28', '38408', '21990', '5050', '6835', '22962', '12755', '17270', '19482', '15940', '10256,1', '13278', '9276', '26848', '32508,2', '4050', '15315', '21762', '6163', '4579', '15887', '4735', '3239', '10029,92', '5751', '12250', '7540', '22330', '43573', '6201', '48572', '41994', '11817', '21938', '6596', '14725', '2435', '6691', '14498', '13792', '61540', '97000', '4182', '31882', '4435', '6086', '3377', '8067', '3904,3', '16052', '41620', '5545', '6993', '25454', '10775', '2889', '25225', '7400', '3616', '5955', '19008', '22290', '11450,9', '10418', '20985,62', '30000', '11680', '10687', '19880', '7289', '11999', '35825', '3493', '7420', '30630', '13010,94', '23706', '7100', '18700', '34806', '10430', '9526', '13325', '5128', '7895', '21586', '24220', '10274', '13960', '4041,9', '8899', '28170', '9917', '10352', '5438', '30370', '5270', '19218', '8071', '30825', '11154', '16370
4640', '360', '1880,59', '1680', '642,31', '2620', '1140,2', '3240', '2230', '1053', '1090,01', '1833,77', '1720', '1095,89', '2590', '3410', '2400', '687,11', '3283,1', '1160', '370', '2640', '2240', '1010', '896,31', '1283,93', '567,51', '5320', '1002,22', '3670', '1549,18', '3700', '2782,93', '1949,8', '500', '1230', '1730', '1745,7', '1666,28', '1986,88', '1550', '5603,82', '791,56', '4001,34', '605,59', '1144,98', '224,59', '3357,52', '2051,5', '910', '2380', '710', '2030', '1097,86', '1120,93', '1344,33', '440', '728,49', '3170', '960', '7100', '1430', '2260', '1740,19', '4960', '438,19', '830', '1180', '480', '1640', '670', '1480', '3780,1', '2570', '1590', '2810', '1670', '849,19', '2549,52', '1489,45', '880,2', '1440', '2265', '2210', '2960', '961,94', '726,57', '1710', '5170', '4240', '2154,02', '658,42', '4729,07', '1427,4', '2005,15', '1740', '1426,72', '2957,71', '1309,89', '3762,5', '1020', '3870,25', '4884,95', '1830', '1351,06', '2701,26', '1340', '660', '1985,3', '2509,38', '324,16', '6260', '502,1', '2760', '2699,88', '4620', '2820', '1077,03', '724,93', '2080', '2202,69', '2816,25', '3010', '875,09', '2000', '975', '828,51', '339,83', '2058,71', '2989,98', '355,04', '2920', '3610', '589,45', '570', '768,97', '2755,21', '2287,02', '797,16', '2250', '1677,48', '6041,86', '1007,8', '789,23', '3702,8', '450', '3230', '2629,87', '3635,77', '981,71', '2830', '1324,5', '63,31', '1080', '2350', '3285,74', '2751,25', '4530', '1090,8', '5470', '3880', '3070', '1200', '2158,72', '6390', '59,68', '470', '954,34', '783', '2293,65', '704,93', '1179,86', '1090', '1300', '598,5', '660,86', '840,4', '3050', '3940', '4400', '5340', '724,38', '4140', '5076,65', '4350', '668,53', '3360', '4680', '4370', '1088,05', '2320', '678,2', '859,92', '3560', '2702,4', '5110', '1489,13', '856,64', '1098,8', '3180', '4210', '3920', '862,43', '1990', '1176,82', '6070', ' ...
#
#
# ==========
# sample
# {'train'}

# %% [markdown]
# Mожно заметить что некоторые переменные, которые обозначены как строки (например PERSONAL_INCOME) на самом деле числа, но по какой-то причине были распознаны как строки
#
# Причина же что использовалась запятая для разделения не целой части числа..

# %% [markdown]
# Перекодировать их можно например так:

# %%
#Код немного исправил, чтобы изменения появились в датафрейме
df['PERSONAL_INCOME'] = df['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')

# %%
df.PERSONAL_INCOME.describe()
# Out:
# count    3.013300e+04
# mean     1.424053e+04
# std      7.532688e+04
# min      2.400000e+01
# 25%      8.000000e+03
# 50%      1.200000e+04
# 75%      1.650000e+04
# max      1.300000e+07
# Name: PERSONAL_INCOME, dtype: float64

# %%
# Перекодируем схожие строки для возможности работы с ними

'''
CREDIT                        30133 non-null object
FST_PAYMENT                   30133 non-null object
LOAN_AVG_DLQ_AMT              30133 non-null object
LOAN_MAX_DLQ_AMT              30133 non-null object
'''
for x in ['CREDIT', 'FST_PAYMENT', 'LOAN_AVG_DLQ_AMT', 'LOAN_MAX_DLQ_AMT']:
    df[x] = df[x].map(lambda x: x.replace(',', '.')).astype('float')

# %%
# попытка поиска числовых признаков, которые больше категорийные
'''for i in df.columns:
    print(df[i].value_counts())
    AGE
    SOCSTATUS_WORK_FL
    SOCSTATUS_PENS_FL
    GENDER
    CHILD_TOTAL
    DEPENDANTS
    EDUCATION
    MARITAL_STATUS
    GEN_INDUSTRY
    GEN_TITLE
    ORG_TP_STATE
    ORG_TP_FCAPITAL
    FAMILY_INCOME
'''
# Out:
# 'for i in df.columns:\n    print(df[i].value_counts())\n    AGE\n    SOCSTATUS_WORK_FL\n    SOCSTATUS_PENS_FL\n    GENDER\n    CHILD_TOTAL\n    DEPENDANTS\n    EDUCATION\n    MARITAL_STATUS\n    GEN_INDUSTRY\n    GEN_TITLE\n    ORG_TP_STATE\n    ORG_TP_FCAPITAL\n    FAMILY_INCOME\n'

# %% [markdown]
# Такой эффект наблюдается в столбцах `PERSONAL_INCOME`, `CREDIT`, `FST_PAYMENT`, `LOAN_AVG_DLQ_AMT`, `LOAN_MAX_DLQ_AMT`

# %% [markdown]
# ### Теперь ваше небольшое исследование

# %% [markdown]
# #### Задание 1. Есть ли пропуски в данных? Что с ними сделать?
#
# (единственного верного ответа нет - аргументируйте)

# %%
'''
Да, пропуски в данных есть. 

Всего строк - 30132

Данные пропущены в 5 категориальных и 2х числовых столбцах.:

GEN_INDUSTRY                  27420 non-null object
GEN_TITLE                     27420 non-null object
ORG_TP_STATE                  27420 non-null object
ORG_TP_FCAPITAL               27425 non-null object
JOB_DIR                       27420 non-null object
TP_PROVINCE                   29543 non-null object

WORK_TIME                     27416 non-null float64
PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64

1. Значения PREVIOUS_CARD_NUM_UTILIZED нужно заменить на 0 согласно описанию данного признака:
("количество уже утилизированных карт (если пусто - 0)" ), так и сделаем. 
2. Данные, кроме WORK_TIME - числовые, пропущено строк не много, возмем медианное значение из этого 
столбца и заполним пропущеные значения. 
(В будущем можно попробовать подставить среднее т.к. медианное  = 48.0 а среднее = 189.58)

'''
# Out:
# '\nДа, пропуски в данных есть. \n\nВсего строк - 30132\n\nДанные пропущены в 5 категориальных и 2х числовых столбцах.:\n\nGEN_INDUSTRY                  27420 non-null object\nGEN_TITLE                     27420 non-null object\nORG_TP_STATE                  27420 non-null object\nORG_TP_FCAPITAL               27425 non-null object\nJOB_DIR                       27420 non-null object\nTP_PROVINCE                   29543 non-null object\n\nWORK_TIME                     27416 non-null float64\nPREVIOUS_CARD_NUM_UTILIZED    600 non-null float64\n\n1. Значения PREVIOUS_CARD_NUM_UTILIZED нужно заменить на 0 согласно описанию данного признака:\n("количество уже утилизированных карт (если пусто - 0)" ), так и сделаем. \n2. Данные, кроме WORK_TIME - числовые, пропущено строк не много, возмем медианное значение из этого \nстолбца и заполним пропущеные значения. \n(В будущем можно попробовать подставить среднее т.к. медианное  = 48.0 а среднее = 189.58)\n\n'

# %% [markdown]
# #### Задание 2. Есть ли категориальные признаки? Что с ними делать?

# %%
'''3. С категориальными признаками подобрать данные будет не просто. По этому, после преобразований выше, 
- удалим пустые строки везде, где пропущены строки:

GEN_INDUSTRY                  27420 non-null object
GEN_TITLE                     27420 non-null object
ORG_TP_STATE                  27420 non-null object
ORG_TP_FCAPITAL               27425 non-null object
JOB_DIR                       27420 non-null object
TP_PROVINCE                   29543 non-null object

4. Категориальные признаки, которые являются числовыми - я преобразовал ранее по примеру.

* Очень много числовых признаков, которые больше схожи на категорийные, 
для повышения качества модели можно попытаться сделать двойную конвертацию: Числовой -> Object признак 
-> методом Get_dummies снова в числовой '''
# Out:
# '3. С категориальными признаками подобрать данные будет не просто. По этому, после преобразований выше, \n- удалим пустые строки везде, где пропущены строки:\n\nGEN_INDUSTRY                  27420 non-null object\nGEN_TITLE                     27420 non-null object\nORG_TP_STATE                  27420 non-null object\nORG_TP_FCAPITAL               27425 non-null object\nJOB_DIR                       27420 non-null object\nTP_PROVINCE                   29543 non-null object\n\n4. Категориальные признаки, которые являются числовыми - я преобразовал ранее по примеру.\n\n* Очень много числовых признаков, которые больше схожи на категорийные, \nдля повышения качества модели можно попытаться сделать двойную конвертацию: Числовой -> Object признак \n-> методом Get_dummies снова в числовой '

# %% [markdown]
# #### Задание 3. Фунция предобработки

# %% [markdown]
# Напишите функцию, которая бы
#
# * Удаляло идентификатор `AGREEMENT_RK`
# * Избавлялась от проблем с '.' и ',' в стобцах PERSONAL_INCOME, CREDIT, FST_PAYMENT, LOAN_AVG_DLQ_AMT, LOAN_MAX_DLQ_AMT
# * Что-то делала с пропусками
# * Кодировала категориальные признаки
#
# В результате, ваш датафрейм должен содержать только числа и не содержать пропусков!

# %%
def preproc_data(df_input):
   
    df_output = df_input.copy()

    #0. Удалим идентификатор AGREEMENT_RK
    df_output.drop('AGREEMENT_RK', axis = 1, inplace = True)


    #1. Заменим пропуски на 0
    df_output['PREVIOUS_CARD_NUM_UTILIZED'].fillna(0, inplace = True)

    #2. Подставим медианное значение в пустые строки
    df_wt_m = df_output['WORK_TIME'].median()#это медианное значение
    df_output['WORK_TIME'].fillna(df_wt_m, inplace  = True)
    

    #3 удалим данные, которые пропущены (потери составят около 10%)
    df_output.dropna(inplace = True)
      
    #4 остается 14 категориальных признаков. с помощью метода dummies превратим их в числовые.
    df_output = pd.get_dummies(df_output, columns = ['EDUCATION','MARITAL_STATUS','GEN_INDUSTRY','GEN_TITLE','ORG_TP_STATE', 'ORG_TP_FCAPITAL', 'JOB_DIR','FAMILY_INCOME','REG_ADDRESS_PROVINCE','FACT_ADDRESS_PROVINCE','POSTAL_ADDRESS_PROVINCE','TP_PROVINCE','REGION_NM'])
    print(df_output.info())

    return df_output

# %%
df_preproc = df.pipe(preproc_data)

df_train_preproc = df_preproc.query('sample == "train"').drop(['sample','TARGET'], axis=1)
df_test_preproc = df_preproc.query('sample == "test"').drop(['sample','TARGET'], axis=1)

df_target_train_preproc = df_preproc.query('sample == "train"')['TARGET']
df_target_test_preproc = df_preproc.query('sample == "test"')['TARGET']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26843 entries, 0 to 30132
# Columns: 443 entries, TARGET to REGION_NM_ЮЖНЫЙ
# dtypes: float64(7), int64(31), object(1), uint8(404)
# memory usage: 18.5+ MB
# None

# %% [markdown]
# #### Задание 4. Отделите целевую переменную и остальные признаки
#
# Должно получится:
# * 2 матрицы: X и X_test
# * 2 вектора: y и y_test

# %% [markdown]
# #### Задание 5. Обучение и оценка качества разных моделей

# %%
from sklearn.model_selection import train_test_split
# test_size=0.3, random_state=42

## Your Code Here
X, X_test, y, y_test = train_test_split(df_train_preproc, df_target_train_preproc, test_size = 0.3, random_state = 42)

# %%
# Попробовать следующие "черные ящики": интерфейс одинаковый 
#     fit, 
#     predict, 
#     predict_proba

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

## Your Code Here
tree = DecisionTreeClassifier(random_state=42)
r_f = RandomForestClassifier(random_state=42)
reg = LogisticRegression(random_state=42)

# %%
tree.fit(X,y)
tr_predict = tree.predict(X_test)
tr_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
r_f.fit(X,y)
r_f_predict = r_f.predict(X_test)
r_f_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
reg.fit(X,y)
reg_predict = reg.predict(X_test)
reg_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# Посчитать метрики стандартные
# accuracy, precision, recall

from sklearn.metrics import accuracy_score, precision_score, recall_score

## Your Code Here
def metrics_scores(y_test, predict):
    accuracy = accuracy_score(y_test, predict)
    precition = precision_score(y_test, predict)
    recall = recall_score(y_test, predict)
    return accuracy, precition, recall

# %%
print("Desc Tree")
print(metrics_scores(y_test, tr_predict))
print("Random forest")
print(metrics_scores(y_test, r_f_predict))
print("Logistics regression")
print(metrics_scores(y_test, reg_predict))
# Out:
# Desc Tree
# (0.7858020142471137, 0.14909090909090908, 0.16872427983539096)
# Random forest
# (0.8771800540407763, 0.1111111111111111, 0.00411522633744856)
# Logistics regression
# (0.8801277327437976, 0.0, 0.0)

# %%
# Визуалищировать эти метрики всех моделей на одном графике (чтоб визуально посмотреть)

## Your Code Here
plt.figure(figsize=(20,10), dpi=80)
plt.xlabel('Metrics name')
plt.ylabel('Value')
plt.title('Errors by using different algorithms')
plot1 = plt.plot(['Accuracy', 'Precition', 'Recall'],metrics_scores(y_test,tr_predict), label = 'Desc Tree')
plot2 = plt.plot(['Accuracy', 'Precition', 'Recall'],metrics_scores(y_test,r_f_predict), label = 'Random Forest')
plot3 = plt.plot(['Accuracy', 'Precition', 'Recall'],metrics_scores(y_test,reg_predict), label = 'Logistics Regression')
plt.legend(loc = 'upper right')

# %%
# Потроить roc-кривые всех моделей на одном графике
# Вывести roc_auc каждой моделе

## Your Code Here
from sklearn.metrics import roc_auc_score, roc_curve

fpr, tpr, thresholds = roc_curve(y_test, tr_predict)
plt.figure(figsize=(20, 5))
plt.subplot(131)
plt.plot([0, 1], [0, 1])
plt.plot(fpr, tpr)
plt.ylabel('tpr')
plt.xlabel('fpr')
plt.title('ROC curve Desc. Tree')
plt.xlim((-0.01, 1.01))
plt.ylim((-0.01, 1.01))

#второй график
fpr, tpr, thresholds = roc_curve(y_test, r_f_predict)
plt.subplot(132)
plt.plot(fpr, tpr, color = 'green')
plt.plot([0, 1], [0, 1])
plt.ylabel('tpr')
plt.xlabel('fpr')
plt.title('ROC curve Rand. Forest')
plt.xlim((-0.01, 1.01))
plt.ylim((-0.01, 1.01))
#второй график
fpr, tpr, thresholds = roc_curve(y_test, reg_predict)
plt.subplot(133)
plt.plot([0, 1], [0, 1])
plt.plot(fpr, tpr, color = 'yellow')
plt.ylabel('tpr')
plt.xlabel('fpr')
plt.title('ROC curve Log Reg')
plt.xlim((-0.01, 1.01))
plt.ylim((-0.01, 1.01))
# Out:
# (-0.01, 1.01)

# %%
fpr, tpr, thresholds = roc_curve(y_test, tr_predict)
fpr_1, tpr_1, thresholds = roc_curve(y_test, r_f_predict)
fpr_2, tpr_2, thresholds = roc_curve(y_test, reg_predict)
plt.figure(figsize=(20, 20))
plt.plot([0, 1], [0, 1], color = 'red')
plt.plot(fpr, tpr, label = 'DT', color = 'black')
plt.plot(fpr_1, tpr_1, label = 'RF', color = 'green')
plt.plot(fpr_2, tpr_2, label = 'LR', color = 'yellow')
plt.ylabel('tpr')
plt.xlabel('fpr')
plt.title('ROC curves comparison on different models')
plt.xlim((-0.01, 1.01))
plt.ylim((-0.01, 1.01))
plt.legend()

# %%
from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import StratifiedKFold
import numpy as np
# Сделать k-fold (10 фолдов) кросс-валидацию каждой модели
# И посчитать средний roc_auc
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=123)

## Your Code Here
# for DT
print(np.mean(cross_val_score(
    tree,
    X,
    y,
    scoring='roc_auc',
    cv=10
)))
# Out:
# C:\Users\morvla\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 0.5310289451078096

# %%
#for RF
print(np.mean(cross_val_score(
    r_f,
    X,
    y,
    scoring='roc_auc',
    cv=10
)))
# Out:
# 0.5820744599088415

# %%
#for LR
print(np.mean(cross_val_score(
    reg,
    X,
    y,
    scoring='roc_auc',
    cv=10
)))
# Out:
# 0.6139017167174314

# %%
# Взять лучшую модель и сделать predict (с вероятностями (!!!)) для test выборки


## Your Code Here
reg_predict_train_data = reg.predict(df_test_preproc)

# %%
metrics_scores(df_target_test_preproc, reg_predict_train_data)
# Out:
# (0.8763748681633268, 0.25, 0.0012217470983506415)

# %%
# Померить roc_auc на тесте
fpr, tpr, thresholds = roc_curve(reg_predict_train_data, df_target_test_preproc)
plt.figure(figsize=(20, 20))
plt.plot([0, 1], [0, 1], color = 'red')
plt.plot(fpr, tpr, label = 'DT', color = 'black')
plt.ylabel('tpr')
plt.xlabel('fpr')
plt.title('ROC curve for best k-fold x-validation - Logistic Regression')
plt.xlim((-0.01, 1.01))
plt.ylim((-0.01, 1.01))
plt.legend()
